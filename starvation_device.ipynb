# %%
import matplotlib.pyplot as plt
import matplotlib as matplt
import numpy as np
import pandas as pd
import seaborn as sns
import os
import glob
import math
import statistics
import tables

np.set_printoptions(precision=3, suppress=True)

from matplotlib.gridspec import GridSpec

# %%
starvation_condition = ['>=1', '>=2', '>=3', '>=4']

# %%
gflops_chunk1 = [2161.066682, 8371.361857, 8426.501098, 9897.303576]
steal_req_send_chunk1  = [10918, 3570, 13753, 3302]
successful_steals_chunk1 = [5650, 1943, 2759, 1677]
successful_full_steals_chunk1 = [5650, 1943, 2759, 1677]
perc_succesfull_steals_chunk1 = [51.749405, 54.425770, 20.061078, 50.787402]
perc_succesfull_full_steals_chunk1 = [51.749405, 54.425770, 20.061078, 50.787402]
task_received_chunk1 = [5650, 1943, 2759, 1677]

# %%
gflops_chunk5 = [6868.132761, 6788.168628, 8191.726449, 4758.502502]
steal_req_send_chunk5  = [4440, 4099, 4168, 17571]
successful_steals_chunk5 = [2508, 1697, 2733, 2619]
successful_full_steals_chunk5 = [2508, 1697, 2733, 2619]
perc_succesfull_steals_chunk5 = [56.486486, 41.400342, 65.571017, 14.905242]
perc_succesfull_full_steals_chunk5 = [56.486486, 41.400342, 65.571017, 14.905242]
task_received_chunk5 = [2508, 1697, 2733, 2619]

# %%
gflops_chunk10 = [5935.890637, 5541.320114, 7794.425075, 5963.621194]
steal_req_send_chunk10  = [5069, 5041, 4241, 4345]
successful_steals_chunk10 = [2498, 2584, 1850, 2327]
successful_full_steals_chunk10 = [2498, 2584, 1850, 2327]
perc_succesfull_steals_chunk10 = [49.279937, 51.259671, 43.621787, 53.555811]
perc_succesfull_full_steals_chunk10 = [49.279937, 51.259671, 43.621787, 53.555811]
task_received_chunk10 = [2498, 2584, 1850, 2327]

# %%
fig = plt.figure(figsize=(15, 12))
gs = GridSpec(nrows=3, ncols=2)



ax0 = fig.add_subplot(gs[0, 0])

plt.plot(starvation_condition, gflops_chunk1, color="blue", marker=11, label='Chunk 1')
plt.plot(starvation_condition, gflops_chunk5, color="green", marker=11, label='Chunk 5')
plt.plot(starvation_condition, gflops_chunk10, color="brown", marker=11, label='Chunk 10')

ax0.set_xlabel('#Starvation condition')
ax0.set_ylabel('Performance (GFlops/s)')
plt.legend()

ax1 = fig.add_subplot(gs[0,1])

plt.plot(starvation_condition, steal_req_send_chunk1, color="blue", marker=11, label='Chunk 1')
plt.plot(starvation_condition, steal_req_send_chunk5, color="green", marker=11, label='Chunk 5')
plt.plot(starvation_condition, steal_req_send_chunk10, color="brown", marker=11, label='Chunk 10')

ax1.set_ylabel('#Steal req send')
ax1.set_xlabel('#Starvation condition')
plt.legend()

ax2 = fig.add_subplot(gs[1,0])

plt.plot(starvation_condition, successful_steals_chunk1, color="blue", marker=11, label='Chunk 1')
plt.plot(starvation_condition, successful_steals_chunk5, color="green", marker=11, label='Chunk 5')
plt.plot(starvation_condition, successful_steals_chunk10, color="brown", marker=11, label='Chunk 10')

ax2.set_ylabel('#Successful steals')
ax2.set_xlabel('#Starvation condition')
plt.legend()

ax3 = fig.add_subplot(gs[1,1])

plt.plot(starvation_condition, successful_full_steals_chunk1, color="blue", marker=11, label='Chunk 1')
plt.plot(starvation_condition, successful_full_steals_chunk5, color="green", marker=11, label='Chunk 5')
plt.plot(starvation_condition, successful_full_steals_chunk10, color="brown", marker=11, label='Chunk 10')

ax3.set_ylabel('#Successful full steals')
ax3.set_xlabel('#Starvation condition')
plt.legend()


ax4 = fig.add_subplot(gs[2,0])

plt.plot(starvation_condition, perc_succesfull_steals_chunk1, color="blue", marker=11, label='Chunk 1')
plt.plot(starvation_condition, perc_succesfull_steals_chunk5, color="green", marker=11, label='Chunk 5')
plt.plot(starvation_condition, perc_succesfull_steals_chunk10, color="brown", marker=11, label='Chunk 10')

ax4.set_ylabel('#% successful steals')
ax4.set_xlabel('#Starvation condition')
plt.legend()

ax5 = fig.add_subplot(gs[2,1])

plt.plot(starvation_condition, perc_succesfull_full_steals_chunk1, color="blue", marker=11, label='Chunk 1')
plt.plot(starvation_condition, perc_succesfull_full_steals_chunk5, color="green", marker=11, label='Chunk 5')
plt.plot(starvation_condition, perc_succesfull_full_steals_chunk10, color="brown", marker=11, label='Chunk 10')

ax5.set_ylabel('#% successful full steals')
ax5.set_xlabel('#Starvation condition')
plt.legend()

#plt.legend([],[], frameon=False)

# %%
fig = plt.figure(figsize=(15, 8))
gs = GridSpec(nrows=2, ncols=2)



ax0 = fig.add_subplot(gs[0, 0])

plt.plot(starvation_condition, gflops_chunk1, color="blue", marker=11, label='Chunk 1')
plt.plot(starvation_condition, gflops_chunk5, color="green", marker=11, label='Chunk 5')
plt.plot(starvation_condition, gflops_chunk10, color="brown", marker=11, label='Chunk 10')

ax0.set_xlabel('#Starvation condition')
ax0.set_ylabel('Performance (GFlops/s)')
plt.legend()

ax1 = fig.add_subplot(gs[0,1])

plt.plot(starvation_condition, steal_req_send_chunk1, color="blue", marker=11, label='Chunk 1')
plt.plot(starvation_condition, steal_req_send_chunk5, color="green", marker=11, label='Chunk 5')
plt.plot(starvation_condition, steal_req_send_chunk10, color="brown", marker=11, label='Chunk 10')

ax1.set_ylabel('#Steal req send')
ax1.set_xlabel('#Starvation condition')
plt.legend()




ax2 = fig.add_subplot(gs[1,0])

plt.plot(starvation_condition, perc_succesfull_steals_chunk1, color="blue", marker=11, label='Chunk 1')
plt.plot(starvation_condition, perc_succesfull_steals_chunk5, color="green", marker=11, label='Chunk 5')
plt.plot(starvation_condition, perc_succesfull_steals_chunk10, color="brown", marker=11, label='Chunk 10')

ax2.set_ylabel('#% successful steals')
ax2.set_xlabel('#Starvation condition')
plt.legend()

ax3 = fig.add_subplot(gs[1,1])

plt.plot(starvation_condition, perc_succesfull_full_steals_chunk1, color="blue", marker=11, label='Chunk 1')
plt.plot(starvation_condition, perc_succesfull_full_steals_chunk5, color="green", marker=11, label='Chunk 5')
plt.plot(starvation_condition, perc_succesfull_full_steals_chunk10, color="brown", marker=11, label='Chunk 10')

ax3.set_ylabel('#% successful full steals')
ax3.set_xlabel('#Starvation condition')
plt.legend()

#plt.legend([],[], frameon=False)

# %%
fig = plt.figure(figsize=(15, 12))
gs = GridSpec(nrows=3, ncols=2)



ax0 = fig.add_subplot(gs[0, 0])

plt.plot(starvation_condition, gflops_chunk1, color="blue", marker=11, label='Chunk 1')
#plt.plot(starvation_condition, gflops_chunk5, color="green", marker=11, label='Chunk 5')
#plt.plot(starvation_condition, gflops_chunk10, color="brown", marker=11, label='Chunk 10')

ax0.set_xlabel('#Starvation condition')
ax0.set_ylabel('Performance (GFlops/s)')
plt.legend()

ax1 = fig.add_subplot(gs[0,1])

plt.plot(starvation_condition, steal_req_send_chunk1, color="blue", marker=11, label='Chunk 1')
#plt.plot(starvation_condition, steal_req_send_chunk5, color="green", marker=11, label='Chunk 5')
#plt.plot(starvation_condition, steal_req_send_chunk10, color="brown", marker=11, label='Chunk 10')

ax1.set_ylabel('#Steal req send')
ax1.set_xlabel('#Starvation condition')
plt.legend()

ax2 = fig.add_subplot(gs[1,0])

plt.plot(starvation_condition, successful_steals_chunk1, color="blue", marker=11, label='Chunk 1')
#plt.plot(starvation_condition, successful_steals_chunk5, color="green", marker=11, label='Chunk 5')
#plt.plot(starvation_condition, successful_steals_chunk10, color="brown", marker=11, label='Chunk 10')

ax2.set_ylabel('#Successful steals')
ax2.set_xlabel('#Starvation condition')
plt.legend()

ax3 = fig.add_subplot(gs[1,1])

plt.plot(starvation_condition, successful_full_steals_chunk1, color="blue", marker=11, label='Chunk 1')
#plt.plot(starvation_condition, successful_full_steals_chunk5, color="green", marker=11, label='Chunk 5')
#plt.plot(starvation_condition, successful_full_steals_chunk10, color="brown", marker=11, label='Chunk 10')

ax3.set_ylabel('#Successful full steals')
ax3.set_xlabel('#Starvation condition')
plt.legend()


ax4 = fig.add_subplot(gs[2,0])

plt.plot(starvation_condition, perc_succesfull_steals_chunk1, color="blue", marker=11, label='Chunk 1')
#plt.plot(starvation_condition, perc_succesfull_steals_chunk5, color="green", marker=11, label='Chunk 5')
#plt.plot(starvation_condition, perc_succesfull_steals_chunk10, color="brown", marker=11, label='Chunk 10')

ax4.set_ylabel('% Successful steals')
ax4.set_xlabel('#Starvation condition')
plt.legend()

ax5 = fig.add_subplot(gs[2,1])

plt.plot(starvation_condition, perc_succesfull_full_steals_chunk1, color="blue", marker=11, label='Chunk 1')
#plt.plot(starvation_condition, perc_succesfull_full_steals_chunk5, color="green", marker=11, label='Chunk 5')
#plt.plot(starvation_condition, perc_succesfull_full_steals_chunk10, color="brown", marker=11, label='Chunk 10')

ax5.set_ylabel('% Successful full steals')
ax5.set_xlabel('#Starvation condition')
plt.legend()

#plt.legend([],[], frameon=False)

# %%
gflops_chunk1_starve = [2161.066682, 8371.361857, 8426.501098, 9897.303576]
steal_req_send_chunk1_starve  = [7371, 2575, 7959, 2105]
successful_steals_chunk1_starve = [1955, 779, 552, 553]
successful_full_steals_chunk1_starve = [1955, 779, 552, 553]
perc_succesfull_steals_chunk1_starve = [26.522860, 30.252427, 6.935545, 26.270784]
perc_succesfull_full_steals_chunk1_starve = [26.522860, 30.252427, 6.935545, 26.270784]
task_received_chunk1_starve = [1955, 779, 552, 553]

# %%
fig = plt.figure(figsize=(15, 12))
gs = GridSpec(nrows=3, ncols=2)



ax0 = fig.add_subplot(gs[0, 0])

plt.plot(starvation_condition, gflops_chunk1, color="brown", marker=11)


ax0.set_xlabel('#Starvation condition')
ax0.set_ylabel('Performance (GFlops/s)')
#plt.legend()

ax1 = fig.add_subplot(gs[0,1])

plt.plot(starvation_condition, steal_req_send_chunk1, color="blue", marker=11, label='Starving Node')

plt.plot(starvation_condition, steal_req_send_chunk1_starve, color="green", marker=11, label='Busy Node')

ax1.set_ylabel('#Steal req send')
ax1.set_xlabel('#Starvation condition')
plt.legend()

ax2 = fig.add_subplot(gs[1,0])

plt.plot(starvation_condition, successful_steals_chunk1, color="blue", marker=11, label='Starving Node')

plt.plot(starvation_condition, successful_steals_chunk1_starve, color="green", marker=11, label='Busy Node')


ax2.set_ylabel('#Successful steals')
ax2.set_xlabel('#Starvation condition')
plt.legend()

ax3 = fig.add_subplot(gs[1,1])

plt.plot(starvation_condition, successful_full_steals_chunk1, color="blue", marker=11, label='Starving Node')

plt.plot(starvation_condition, successful_full_steals_chunk1_starve, color="green", marker=11, label='Busy Node')


ax3.set_ylabel('#Successful full steals')
ax3.set_xlabel('#Starvation condition')
plt.legend()


ax4 = fig.add_subplot(gs[2,0])

plt.plot(starvation_condition, perc_succesfull_steals_chunk1, color="blue", marker=11, label='Starving Node')

plt.plot(starvation_condition, perc_succesfull_steals_chunk1_starve, color="green", marker=11, label='Busy Node')

ax4.set_ylabel('% Successful steals')
ax4.set_xlabel('#Starvation condition')
plt.legend()

ax5 = fig.add_subplot(gs[2,1])

plt.plot(starvation_condition, perc_succesfull_full_steals_chunk1, color="blue", marker=11, label='Starving Node')

plt.plot(starvation_condition, perc_succesfull_full_steals_chunk1_starve, color="green", marker=11, label='Starving Node')

ax5.set_ylabel('% Successful full steals')
ax5.set_xlabel('#Starvation condition')
plt.legend()

#plt.legend([],[], frameon=False)

# %%
fig = plt.figure(figsize=(15, 8))
gs = GridSpec(nrows=2, ncols=2)



ax0 = fig.add_subplot(gs[0, 0])

plt.plot(starvation_condition, gflops_chunk1, color="brown", marker=11)


ax0.set_xlabel('# Starvation condition', fontsize=14)
ax0.set_ylabel('Performance (GFlops/s)', fontsize=14)
ax0.set_title('(a)', loc='left')

ax1 = fig.add_subplot(gs[0,1])

plt.plot(starvation_condition, steal_req_send_chunk1, color="blue", marker=11, label='Starving Node')

plt.plot(starvation_condition, steal_req_send_chunk1_starve, color="green", marker=11, label='Busy Node')

ax1.set_ylabel('# Steal req send', fontsize=14)
ax1.set_xlabel('# Starvation condition', fontsize=14)
ax1.set_title('(b)', loc='left')
plt.legend()

ax2 = fig.add_subplot(gs[1,0])

plt.plot(starvation_condition, successful_steals_chunk1, color="blue", marker=11, label='Starving Node')

plt.plot(starvation_condition, successful_steals_chunk1_starve, color="green", marker=11, label='Busy Node')

ax2.set_ylabel('# Successful steals', fontsize=14)
ax2.set_xlabel('# Starvation condition', fontsize=14)
ax2.set_title('(c)', loc='left')
plt.legend()


ax3 = fig.add_subplot(gs[1,1])

plt.plot(starvation_condition, perc_succesfull_steals_chunk1, color="blue", marker=11, label='Starving Node')

plt.plot(starvation_condition, perc_succesfull_steals_chunk1_starve, color="green", marker=11, label='Busy Node')

ax3.set_ylabel('% Successful steals', fontsize=14)
ax3.set_xlabel('# Starvation condition', fontsize=14)
ax3.set_title('(d)', loc='left')
plt.legend()

fig.savefig('starvation_dev_condition.png', dpi=300, bbox_inches='tight')

#plt.legend([],[], frameon=False)

# %% [markdown]
# *****
# * Stricter condition does not quarantee less steal requests
# * More steal requests does quarantee more task migration
# * Higher % succesful steal does not seem to quarantee higher performance
#
# *****
# * The performance is bad when the busy node laso requests tasks
# * The Only way to de it is to unrol the DAG to find future tasks
# * But that is goingto be a vey costly excersice, so we cannot do it now
#
# *****
# * The bad performance comes from migrating tasks to busy nodes
